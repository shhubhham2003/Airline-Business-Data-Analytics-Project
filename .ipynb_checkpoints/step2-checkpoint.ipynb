# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load CSV file
df = pd.read_csv('refined_dataset.csv')

# Basic exploration
print("Dataset shape:", df.shape)
df.head()
# Out:
# Dataset shape: (89174, 26)
#    customer_id gender customer_type  age type_of_travel     class  \
# 0        70172      M         loyal   13       personal  eco plus
# 1         5047      M      disloyal   25       business  business
# 2       110028      F         loyal   26       business  business
# 3        24026      F         loyal   25       business  business
# 4       119299      M         loyal   61       business  business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenience  \
# 0              460                    3.0                                 4.0
# 1              235                    3.0                                 2.0
# 2             1142                    2.0                                 2.0
# 3              562                    2.0                                 5.0
# 4              214                    3.0                                 3.0
#
#    ease_of_online_booking  ...  leg_room_service  baggage_handling  \
# 0                     3.0  ...               3.0                 4
# 1                     3.0  ...               5.0                 3
# 2                     2.0  ...               3.0                 4
# 3                     5.0  ...               5.0                 3
# 4                     3.0  ...               4.0                 4
#
#    checkin_service  inflight_service  cleanliness  departure_delay_in_minutes  \
# 0              4.0               5.0          5.0                          25
# 1              1.0               4.0          1.0                           1
# 2              4.0               4.0          5.0                           0
# 3              1.0               4.0          2.0                          11
# 4              3.0               3.0          3.0                           0
#
#    arrival_delay_in_minutes  time_recovered_in_minutes  time_recovery_status  \
# 0                        18                          7             recovered
# 1                         6                         -5              worsened
# 2                         0                          0                  same
# 3                         9                          2             recovered
# 4                         0                          0                  same
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 26 columns]

# %%
print(df['satisfaction'].unique())
# Out:
# ['neutral or dissatisfied' 'satisfied']

# %%
# converting satisfaction to binary (boolean)
df['satisfaction_bool'] = df['satisfaction'].map({
    'neutral or dissatisfied': 0,
    'satisfied': 1
})

# %%
df.head()
# Out:
#    customer_id gender customer_type  age type_of_travel     class  \
# 0        70172      M         loyal   13       personal  eco plus
# 1         5047      M      disloyal   25       business  business
# 2       110028      F         loyal   26       business  business
# 3        24026      F         loyal   25       business  business
# 4       119299      M         loyal   61       business  business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenience  \
# 0              460                    3.0                                 4.0
# 1              235                    3.0                                 2.0
# 2             1142                    2.0                                 2.0
# 3              562                    2.0                                 5.0
# 4              214                    3.0                                 3.0
#
#    ease_of_online_booking  ...  baggage_handling  checkin_service  \
# 0                     3.0  ...                 4              4.0
# 1                     3.0  ...                 3              1.0
# 2                     2.0  ...                 4              4.0
# 3                     5.0  ...                 3              1.0
# 4                     3.0  ...                 4              3.0
#
#    inflight_service  cleanliness  departure_delay_in_minutes  \
# 0               5.0          5.0                          25
# 1               4.0          1.0                           1
# 2               4.0          5.0                           0
# 3               4.0          2.0                          11
# 4               3.0          3.0                           0
#
#    arrival_delay_in_minutes  time_recovered_in_minutes  time_recovery_status  \
# 0                        18                          7             recovered
# 1                         6                         -5              worsened
# 2                         0                          0                  same
# 3                         9                          2             recovered
# 4                         0                          0                  same
#
#               satisfaction  satisfaction_bool
# 0  neutral or dissatisfied                  0
# 1  neutral or dissatisfied                  0
# 2                satisfied                  1
# 3  neutral or dissatisfied                  0
# 4                satisfied                  1
#
# [5 rows x 27 columns]

# %%
## code to create customer segmentation: high or low using - customer_type ['loyal' 'disloyal'], type_of_travel ['personal' 'business'], class [['eco plus' 'business' 'eco']]

customer_type_score = {'loyal': 1, 'disloyal': 0}
travel_type_score = {'business': 1, 'personal': 0}
class_score = {'eco': 0, 'eco plus': 1, 'business': 2}

df['segment_score'] = (
    df['customer_type'].map(customer_type_score) +
    df['type_of_travel'].map(travel_type_score) +
    df['class'].map(class_score)
)

score_to_segment = {0: 'low', 1: 'low', 2: 'mid', 3: 'high', 4: 'high'}
df['customer_value'] = df['segment_score'].map(score_to_segment)

cols = df.columns.tolist()
cust_idx = cols.index('customer_value')
id_idx = cols.index('customer_id')

cols.insert(id_idx + 1, cols.pop(cust_idx))
df = df[cols]

# %%
df.head()
# Out:
#    customer_id customer_value gender customer_type  age type_of_travel  \
# 0        70172            mid      M         loyal   13       personal
# 1         5047           high      M      disloyal   25       business
# 2       110028           high      F         loyal   26       business
# 3        24026           high      F         loyal   25       business
# 4       119299           high      M         loyal   61       business
#
#       class  flight_distance  inflight_wifi_service  \
# 0  eco plus              460                    3.0
# 1  business              235                    3.0
# 2  business             1142                    2.0
# 3  business              562                    2.0
# 4  business              214                    3.0
#
#    departure_arrival_time_convenience  ...  checkin_service  inflight_service  \
# 0                                 4.0  ...              4.0               5.0
# 1                                 2.0  ...              1.0               4.0
# 2                                 2.0  ...              4.0               4.0
# 3                                 5.0  ...              1.0               4.0
# 4                                 3.0  ...              3.0               3.0
#
#    cleanliness  departure_delay_in_minutes  arrival_delay_in_minutes  \
# 0          5.0                          25                        18
# 1          1.0                           1                         6
# 2          5.0                           0                         0
# 3          2.0                          11                         9
# 4          3.0                           0                         0
#
#    time_recovered_in_minutes  time_recovery_status             satisfaction  \
# 0                          7             recovered  neutral or dissatisfied
# 1                         -5              worsened  neutral or dissatisfied
# 2                          0                  same                satisfied
# 3                          2             recovered  neutral or dissatisfied
# 4                          0                  same                satisfied
#
#    satisfaction_bool  segment_score
# 0                  0              2
# 1                  0              3
# 2                  1              4
# 3                  0              4
# 4                  1              4
#
# [5 rows x 29 columns]

# %%
df = df.drop('segment_score', axis=1)

# %%
df.head()
# Out:
#    customer_id customer_value gender customer_type  age type_of_travel  \
# 0        70172            mid      M         loyal   13       personal
# 1         5047           high      M      disloyal   25       business
# 2       110028           high      F         loyal   26       business
# 3        24026           high      F         loyal   25       business
# 4       119299           high      M         loyal   61       business
#
#       class  flight_distance  inflight_wifi_service  \
# 0  eco plus              460                    3.0
# 1  business              235                    3.0
# 2  business             1142                    2.0
# 3  business              562                    2.0
# 4  business              214                    3.0
#
#    departure_arrival_time_convenience  ...  baggage_handling  checkin_service  \
# 0                                 4.0  ...                 4              4.0
# 1                                 2.0  ...                 3              1.0
# 2                                 2.0  ...                 4              4.0
# 3                                 5.0  ...                 3              1.0
# 4                                 3.0  ...                 4              3.0
#
#    inflight_service  cleanliness  departure_delay_in_minutes  \
# 0               5.0          5.0                          25
# 1               4.0          1.0                           1
# 2               4.0          5.0                           0
# 3               4.0          2.0                          11
# 4               3.0          3.0                           0
#
#    arrival_delay_in_minutes  time_recovered_in_minutes  time_recovery_status  \
# 0                        18                          7             recovered
# 1                         6                         -5              worsened
# 2                         0                          0                  same
# 3                         9                          2             recovered
# 4                         0                          0                  same
#
#               satisfaction  satisfaction_bool
# 0  neutral or dissatisfied                  0
# 1  neutral or dissatisfied                  0
# 2                satisfied                  1
# 3  neutral or dissatisfied                  0
# 4                satisfied                  1
#
# [5 rows x 28 columns]

# %%
# verification of logic applied
verification_table = (
    df[['customer_type', 'type_of_travel', 'class', 'customer_value']]
    .drop_duplicates()
    .sort_values(by=['customer_type', 'type_of_travel', 'class'])
    .reset_index(drop=True)
)

verification_table
# Out:
#    customer_type type_of_travel     class customer_value
# 0       disloyal       business  business           high
# 1       disloyal       business       eco            low
# 2       disloyal       business  eco plus            mid
# 3       disloyal       personal  business            mid
# 4       disloyal       personal       eco            low
# 5       disloyal       personal  eco plus            low
# 6          loyal       business  business           high
# 7          loyal       business       eco            mid
# 8          loyal       business  eco plus           high
# 9          loyal       personal  business           high
# 10         loyal       personal       eco            low
# 11         loyal       personal  eco plus            mid

# %%
df.to_csv('prepared_and_cleaned_dataset.csv', index=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 ## code to divide ratings into product and services
# ----> 2 print(df.describe())
#
# NameError: name 'df' is not defined
