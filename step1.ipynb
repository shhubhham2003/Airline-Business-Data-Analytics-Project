# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Loading CSV file
df = pd.read_csv('raw dataset.csv')

# Basic exploration
print("Dataset shape:", df.shape)
# Out:
# Dataset shape: (103904, 25)

# %%
print("\nFirst 5 rows:")
df.head()
# Out:
# First 5 rows:
#    serial_number      id  gender      customer_type  age   type_of_travel  \
# 0              0   70172    Male     Loyal Customer   13  Personal Travel
# 1              1    5047    Male  disloyal Customer   25  Business travel
# 2              2  110028  Female     Loyal Customer   26  Business travel
# 3              3   24026  Female     Loyal Customer   25  Business travel
# 4              4  119299    Male     Loyal Customer   61  Business travel
#
#       class  flight_distance  inflight_wifi_service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    departure_arrival_time_convenience  ...  inflight_entertainment  \
# 0                                   4  ...                       5
# 1                                   2  ...                       1
# 2                                   2  ...                       5
# 3                                   5  ...                       2
# 4                                   3  ...                       3
#
#    on_board_service  leg_room_service  baggage_handling  checkin_service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    inflight_service  cleanliness  departure_delay_in_minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    arrival_delay_in_minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 25 columns]

# %%
print("\nMissing values:")
df.isnull().sum()
# Out:
# Missing values:
# serial_number                           0
# id                                      0
# gender                                  0
# customer_type                           0
# age                                     0
# type_of_travel                          0
# class                                   0
# flight_distance                         0
# inflight_wifi_service                   0
# departure_arrival_time_convenience      0
# ease_of_online_booking                  0
# gate_location                           0
# food_and_drink                          0
# online_boarding                         0
# seat_comfort                            0
# inflight_entertainment                  0
# on_board_service                        0
# leg_room_service                        0
# baggage_handling                        0
# checkin_service                         0
# inflight_service                        0
# cleanliness                             0
# departure_delay_in_minutes              0
# arrival_delay_in_minutes              310
# satisfaction                            0
# dtype: int64

# %%
print("\nData types:")
df.dtypes
# Out:
# Data types:
# serial_number                           int64
# id                                      int64
# gender                                 object
# customer_type                          object
# age                                     int64
# type_of_travel                         object
# class                                  object
# flight_distance                         int64
# inflight_wifi_service                   int64
# departure_arrival_time_convenience      int64
# ease_of_online_booking                  int64
# gate_location                           int64
# food_and_drink                          int64
# online_boarding                         int64
# seat_comfort                            int64
# inflight_entertainment                  int64
# on_board_service                        int64
# leg_room_service                        int64
# baggage_handling                        int64
# checkin_service                         int64
# inflight_service                        int64
# cleanliness                             int64
# departure_delay_in_minutes              int64
# arrival_delay_in_minutes              float64
# satisfaction                           object
# dtype: object

# %%
print("\nBasic statistics:")
df.describe()
# Out:
# Basic statistics:
#        serial_number             id            age  flight_distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        inflight_wifi_service  departure_arrival_time_convenience  \
# count          103904.000000                       103904.000000
# mean                2.729683                            3.060296
# std                 1.327829                            1.525075
# min                 0.000000                            0.000000
# 25%                 2.000000                            2.000000
# 50%                 3.000000                            3.000000
# 75%                 4.000000                            4.000000
# max                 5.000000                            5.000000
#
#        ease_of_online_booking  gate_location  food_and_drink  online_boarding  \
# count           103904.000000  103904.000000   103904.000000    103904.000000
# mean                 2.756901       2.976883        3.202129         3.250375
# std                  1.398929       1.277621        1.329533         1.349509
# min                  0.000000       0.000000        0.000000         0.000000
# 25%                  2.000000       2.000000        2.000000         2.000000
# 50%                  3.000000       3.000000        3.000000         3.000000
# 75%                  4.000000       4.000000        4.000000         4.000000
# max                  5.000000       5.000000        5.000000         5.000000
#
#         seat_comfort  inflight_entertainment  on_board_service  \
# count  103904.000000           103904.000000     103904.000000
# mean        3.439396                3.358158          3.382363
# std         1.319088                1.332991          1.288354
# min         0.000000                0.000000          0.000000
# 25%         2.000000                2.000000          2.000000
# 50%         4.000000                4.000000          4.000000
# 75%         5.000000                4.000000          4.000000
# max         5.000000                5.000000          5.000000
#
#        leg_room_service  baggage_handling  checkin_service  inflight_service  \
# count     103904.000000     103904.000000    103904.000000     103904.000000
# mean           3.351055          3.631833         3.304290          3.640428
# std            1.315605          1.180903         1.265396          1.175663
# min            0.000000          1.000000         0.000000          0.000000
# 25%            2.000000          3.000000         3.000000          3.000000
# 50%            4.000000          4.000000         3.000000          4.000000
# 75%            4.000000          5.000000         4.000000          5.000000
# max            5.000000          5.000000         5.000000          5.000000
#
#          cleanliness  departure_delay_in_minutes  arrival_delay_in_minutes
# count  103904.000000               103904.000000             103594.000000
# mean        3.286351                   14.815618                 15.178678
# std         1.312273                   38.230901                 38.698682
# min         0.000000                    0.000000                  0.000000
# 25%         2.000000                    0.000000                  0.000000
# 50%         3.000000                    0.000000                  0.000000
# 75%         4.000000                   12.000000                 13.000000
# max         5.000000                 1592.000000               1584.000000

# %%
df = df.drop('serial_number', axis=1)

# %%
df.describe()
# Out:
#                   id            age  flight_distance  inflight_wifi_service  \
# count  103904.000000  103904.000000    103904.000000          103904.000000
# mean    64924.210502      39.379706      1189.448375               2.729683
# std     37463.812252      15.114964       997.147281               1.327829
# min         1.000000       7.000000        31.000000               0.000000
# 25%     32533.750000      27.000000       414.000000               2.000000
# 50%     64856.500000      40.000000       843.000000               3.000000
# 75%     97368.250000      51.000000      1743.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        departure_arrival_time_convenience  ease_of_online_booking  \
# count                       103904.000000           103904.000000
# mean                             3.060296                2.756901
# std                              1.525075                1.398929
# min                              0.000000                0.000000
# 25%                              2.000000                2.000000
# 50%                              3.000000                3.000000
# 75%                              4.000000                4.000000
# max                              5.000000                5.000000
#
#        gate_location  food_and_drink  online_boarding   seat_comfort  \
# count  103904.000000   103904.000000    103904.000000  103904.000000
# mean        2.976883        3.202129         3.250375       3.439396
# std         1.277621        1.329533         1.349509       1.319088
# min         0.000000        0.000000         0.000000       0.000000
# 25%         2.000000        2.000000         2.000000       2.000000
# 50%         3.000000        3.000000         3.000000       4.000000
# 75%         4.000000        4.000000         4.000000       5.000000
# max         5.000000        5.000000         5.000000       5.000000
#
#        inflight_entertainment  on_board_service  leg_room_service  \
# count           103904.000000     103904.000000     103904.000000
# mean                 3.358158          3.382363          3.351055
# std                  1.332991          1.288354          1.315605
# min                  0.000000          0.000000          0.000000
# 25%                  2.000000          2.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  4.000000          4.000000          4.000000
# max                  5.000000          5.000000          5.000000
#
#        baggage_handling  checkin_service  inflight_service    cleanliness  \
# count     103904.000000    103904.000000     103904.000000  103904.000000
# mean           3.631833         3.304290          3.640428       3.286351
# std            1.180903         1.265396          1.175663       1.312273
# min            1.000000         0.000000          0.000000       0.000000
# 25%            3.000000         3.000000          3.000000       2.000000
# 50%            4.000000         3.000000          4.000000       3.000000
# 75%            5.000000         4.000000          5.000000       4.000000
# max            5.000000         5.000000          5.000000       5.000000
#
#        departure_delay_in_minutes  arrival_delay_in_minutes
# count               103904.000000             103594.000000
# mean                    14.815618                 15.178678
# std                     38.230901                 38.698682
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# 50%                      0.000000                  0.000000
# 75%                     12.000000                 13.000000
# max                   1592.000000               1584.000000

# %%
df['satisfaction'] = df['satisfaction'].astype(str)

# %%
df.dtypes
# Out:
# id                                      int64
# gender                                 object
# customer_type                          object
# age                                     int64
# type_of_travel                         object
# class                                  object
# flight_distance                         int64
# inflight_wifi_service                   int64
# departure_arrival_time_convenience      int64
# ease_of_online_booking                  int64
# gate_location                           int64
# food_and_drink                          int64
# online_boarding                         int64
# seat_comfort                            int64
# inflight_entertainment                  int64
# on_board_service                        int64
# leg_room_service                        int64
# baggage_handling                        int64
# checkin_service                         int64
# inflight_service                        int64
# cleanliness                             int64
# departure_delay_in_minutes              int64
# arrival_delay_in_minutes              float64
# satisfaction                           object
# dtype: object

# %%
df['arrival_delay_in_minutes'] = pd.to_numeric(df['arrival_delay_in_minutes'], errors='coerce').fillna(0).astype(int)

# %%
df.head()
# Out:
#        id  gender      customer_type  age   type_of_travel     class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenience  \
# 0              460                      3                                   4
# 1              235                      3                                   2
# 2             1142                      2                                   2
# 3              562                      2                                   5
# 4              214                      3                                   3
#
#    ease_of_online_booking  ...  inflight_entertainment  on_board_service  \
# 0                       3  ...                       5                 4
# 1                       3  ...                       1                 1
# 2                       2  ...                       5                 4
# 3                       5  ...                       2                 2
# 4                       3  ...                       3                 3
#
#    leg_room_service  baggage_handling  checkin_service  inflight_service  \
# 0                 3                 4                4                 5
# 1                 5                 3                1                 4
# 2                 3                 4                4                 4
# 3                 5                 3                1                 4
# 4                 4                 4                3                 3
#
#    cleanliness  departure_delay_in_minutes  arrival_delay_in_minutes  \
# 0            5                          25                        18
# 1            1                           1                         6
# 2            5                           0                         0
# 3            2                          11                         9
# 4            3                           0                         0
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 24 columns]

# %%
df['gender'] = df['gender'].str[0].str.upper()
df['customer_type'] = df['customer_type'].str.lower().str.extract(r'(loyal|disloyal)')[0]
df['class'] = df['class'].str.lower()

# %%
df.head()
# Out:
#        id gender customer_type  age   type_of_travel     class  \
# 0   70172      M         loyal   13  Personal Travel  eco plus
# 1    5047      M      disloyal   25  Business travel  business
# 2  110028      F         loyal   26  Business travel  business
# 3   24026      F         loyal   25  Business travel  business
# 4  119299      M         loyal   61  Business travel  business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenience  \
# 0              460                      3                                   4
# 1              235                      3                                   2
# 2             1142                      2                                   2
# 3              562                      2                                   5
# 4              214                      3                                   3
#
#    ease_of_online_booking  ...  inflight_entertainment  on_board_service  \
# 0                       3  ...                       5                 4
# 1                       3  ...                       1                 1
# 2                       2  ...                       5                 4
# 3                       5  ...                       2                 2
# 4                       3  ...                       3                 3
#
#    leg_room_service  baggage_handling  checkin_service  inflight_service  \
# 0                 3                 4                4                 5
# 1                 5                 3                1                 4
# 2                 3                 4                4                 4
# 3                 5                 3                1                 4
# 4                 4                 4                3                 3
#
#    cleanliness  departure_delay_in_minutes  arrival_delay_in_minutes  \
# 0            5                          25                        18
# 1            1                           1                         6
# 2            5                           0                         0
# 3            2                          11                         9
# 4            3                           0                         0
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 24 columns]

# %%
df['type_of_travel'] = df['type_of_travel'].str.lower().str.replace(' travel', '').str.strip()

# %%
df.head()
# Out:
#        id gender customer_type  age type_of_travel     class  flight_distance  \
# 0   70172      M         loyal   13       personal  eco plus              460
# 1    5047      M      disloyal   25       business  business              235
# 2  110028      F         loyal   26       business  business             1142
# 3   24026      F         loyal   25       business  business              562
# 4  119299      M         loyal   61       business  business              214
#
#    inflight_wifi_service  departure_arrival_time_convenience  \
# 0                      3                                   4
# 1                      3                                   2
# 2                      2                                   2
# 3                      2                                   5
# 4                      3                                   3
#
#    ease_of_online_booking  ...  inflight_entertainment  on_board_service  \
# 0                       3  ...                       5                 4
# 1                       3  ...                       1                 1
# 2                       2  ...                       5                 4
# 3                       5  ...                       2                 2
# 4                       3  ...                       3                 3
#
#    leg_room_service  baggage_handling  checkin_service  inflight_service  \
# 0                 3                 4                4                 5
# 1                 5                 3                1                 4
# 2                 3                 4                4                 4
# 3                 5                 3                1                 4
# 4                 4                 4                3                 3
#
#    cleanliness  departure_delay_in_minutes  arrival_delay_in_minutes  \
# 0            5                          25                        18
# 1            1                           1                         6
# 2            5                           0                         0
# 3            2                          11                         9
# 4            3                           0                         0
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 24 columns]

# %%
df = df.rename(columns={'id': 'customer_id'})

# %%
df.head()
# Out:
#    customer_id gender customer_type  age type_of_travel     class  \
# 0        70172      M         loyal   13       personal  eco plus
# 1         5047      M      disloyal   25       business  business
# 2       110028      F         loyal   26       business  business
# 3        24026      F         loyal   25       business  business
# 4       119299      M         loyal   61       business  business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenience  \
# 0              460                      3                                   4
# 1              235                      3                                   2
# 2             1142                      2                                   2
# 3              562                      2                                   5
# 4              214                      3                                   3
#
#    ease_of_online_booking  ...  inflight_entertainment  on_board_service  \
# 0                       3  ...                       5                 4
# 1                       3  ...                       1                 1
# 2                       2  ...                       5                 4
# 3                       5  ...                       2                 2
# 4                       3  ...                       3                 3
#
#    leg_room_service  baggage_handling  checkin_service  inflight_service  \
# 0                 3                 4                4                 5
# 1                 5                 3                1                 4
# 2                 3                 4                4                 4
# 3                 5                 3                1                 4
# 4                 4                 4                3                 3
#
#    cleanliness  departure_delay_in_minutes  arrival_delay_in_minutes  \
# 0            5                          25                        18
# 1            1                           1                         6
# 2            5                           0                         0
# 3            2                          11                         9
# 4            3                           0                         0
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 24 columns]

# %%
initial_count = len(df)
df = df.drop_duplicates(subset='customer_id')
removed_count = initial_count - len(df)
print(f"Removed {removed_count} duplicate records")
# Out:
# Removed 0 duplicate records

# %%
df.describe()
# Out:
#          customer_id            age  flight_distance  inflight_wifi_service  \
# count  103904.000000  103904.000000    103904.000000          103904.000000
# mean    64924.210502      39.379706      1189.448375               2.729683
# std     37463.812252      15.114964       997.147281               1.327829
# min         1.000000       7.000000        31.000000               0.000000
# 25%     32533.750000      27.000000       414.000000               2.000000
# 50%     64856.500000      40.000000       843.000000               3.000000
# 75%     97368.250000      51.000000      1743.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        departure_arrival_time_convenience  ease_of_online_booking  \
# count                       103904.000000           103904.000000
# mean                             3.060296                2.756901
# std                              1.525075                1.398929
# min                              0.000000                0.000000
# 25%                              2.000000                2.000000
# 50%                              3.000000                3.000000
# 75%                              4.000000                4.000000
# max                              5.000000                5.000000
#
#        gate_location  food_and_drink  online_boarding   seat_comfort  \
# count  103904.000000   103904.000000    103904.000000  103904.000000
# mean        2.976883        3.202129         3.250375       3.439396
# std         1.277621        1.329533         1.349509       1.319088
# min         0.000000        0.000000         0.000000       0.000000
# 25%         2.000000        2.000000         2.000000       2.000000
# 50%         3.000000        3.000000         3.000000       4.000000
# 75%         4.000000        4.000000         4.000000       5.000000
# max         5.000000        5.000000         5.000000       5.000000
#
#        inflight_entertainment  on_board_service  leg_room_service  \
# count           103904.000000     103904.000000     103904.000000
# mean                 3.358158          3.382363          3.351055
# std                  1.332991          1.288354          1.315605
# min                  0.000000          0.000000          0.000000
# 25%                  2.000000          2.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  4.000000          4.000000          4.000000
# max                  5.000000          5.000000          5.000000
#
#        baggage_handling  checkin_service  inflight_service    cleanliness  \
# count     103904.000000    103904.000000     103904.000000  103904.000000
# mean           3.631833         3.304290          3.640428       3.286351
# std            1.180903         1.265396          1.175663       1.312273
# min            1.000000         0.000000          0.000000       0.000000
# 25%            3.000000         3.000000          3.000000       2.000000
# 50%            4.000000         3.000000          4.000000       3.000000
# 75%            5.000000         4.000000          5.000000       4.000000
# max            5.000000         5.000000          5.000000       5.000000
#
#        departure_delay_in_minutes  arrival_delay_in_minutes
# count               103904.000000             103904.000000
# mean                    14.815618                 15.133392
# std                     38.230901                 38.649776
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# 50%                      0.000000                  0.000000
# 75%                     12.000000                 13.000000
# max                   1592.000000               1584.000000

# %%
## code to replace all product or service 0 ratings with NaN
service_columns = [
    'inflight_wifi_service', 'departure_arrival_time_convenience',
    'ease_of_online_booking', 'gate_location', 'food_and_drink',
    'online_boarding', 'seat_comfort', 'inflight_entertainment',
    'on_board_service', 'leg_room_service', 'baggage_handling',
    'checkin_service', 'inflight_service', 'cleanliness'
]
df[service_columns] = df[service_columns].replace(0, np.nan)
# Out:
#    customer_id gender customer_type  age type_of_travel     class  \
# 0        70172      M         loyal   13       personal  eco plus
# 1         5047      M      disloyal   25       business  business
# 2       110028      F         loyal   26       business  business
# 3        24026      F         loyal   25       business  business
# 4       119299      M         loyal   61       business  business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenience  \
# 0              460                    3.0                                 4.0
# 1              235                    3.0                                 2.0
# 2             1142                    2.0                                 2.0
# 3              562                    2.0                                 5.0
# 4              214                    3.0                                 3.0
#
#    ease_of_online_booking  ...  inflight_entertainment  on_board_service  \
# 0                     3.0  ...                     5.0               4.0
# 1                     3.0  ...                     1.0               1.0
# 2                     2.0  ...                     5.0               4.0
# 3                     5.0  ...                     2.0               2.0
# 4                     3.0  ...                     3.0               3.0
#
#    leg_room_service  baggage_handling  checkin_service  inflight_service  \
# 0               3.0                 4              4.0               5.0
# 1               5.0                 3              1.0               4.0
# 2               3.0                 4              4.0               4.0
# 3               5.0                 3              1.0               4.0
# 4               4.0                 4              3.0               3.0
#
#    cleanliness  departure_delay_in_minutes  arrival_delay_in_minutes  \
# 0          5.0                          25                        18
# 1          1.0                           1                         6
# 2          5.0                           0                         0
# 3          2.0                          11                         9
# 4          3.0                           0                         0
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#          customer_id            age  flight_distance  inflight_wifi_service  \
# count  103904.000000  103904.000000    103904.000000          100801.000000
# mean    64924.210502      39.379706      1189.448375               2.813712
# std     37463.812252      15.114964       997.147281               1.257367
# min         1.000000       7.000000        31.000000               1.000000
# 25%     32533.750000      27.000000       414.000000               2.000000
# 50%     64856.500000      40.000000       843.000000               3.000000
# 75%     97368.250000      51.000000      1743.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        departure_arrival_time_convenience  ease_of_online_booking  \
# count                        98604.000000            99417.000000
# mean                             3.224788                2.881328
# std                              1.385790                1.298773
# min                              1.000000                1.000000
# 25%                              2.000000                2.000000
# 50%                              3.000000                3.000000
# 75%                              4.000000                4.000000
# max                              5.000000                5.000000
#
#        gate_location  food_and_drink  online_boarding   seat_comfort  \
# count  103903.000000   103797.000000    101476.000000  103903.000000
# mean        2.976911        3.205430         3.328147       3.439429
# std         1.277594        1.326235         1.267246       1.319051
# min         1.000000        1.000000         1.000000       1.000000
# 25%         2.000000        2.000000         2.000000       2.000000
# 50%         3.000000        3.000000         4.000000       4.000000
# 75%         4.000000        4.000000         4.000000       5.000000
# max         5.000000        5.000000         5.000000       5.000000
#
#        inflight_entertainment  on_board_service  leg_room_service  \
# count            103890.00000     103901.000000     103432.000000
# mean                  3.35861          3.382460          3.366347
# std                   1.33251          1.288245          1.298936
# min                   1.00000          1.000000          1.000000
# 25%                   2.00000          2.000000          2.000000
# 50%                   4.00000          4.000000          4.000000
# 75%                   4.00000          4.000000          4.000000
# max                   5.00000          5.000000          5.000000
#
#        baggage_handling  checkin_service  inflight_service    cleanliness  \
# count     103904.000000    103903.000000     103901.000000  103892.000000
# mean           3.631833         3.304322          3.640533       3.286730
# std            1.180903         1.265360          1.175517       1.311873
# min            1.000000         1.000000          1.000000       1.000000
# 25%            3.000000         3.000000          3.000000       2.000000
# 50%            4.000000         3.000000          4.000000       3.000000
# 75%            5.000000         4.000000          5.000000       4.000000
# max            5.000000         5.000000          5.000000       5.000000
#
#        departure_delay_in_minutes  arrival_delay_in_minutes
# count               103904.000000             103904.000000
# mean                    14.815618                 15.133392
# std                     38.230901                 38.649776
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# 50%                      0.000000                  0.000000
# 75%                     12.000000                 13.000000
# max                   1592.000000               1584.000000

# %%
## code to remove all rows with any one cell blank or null (other than NaN) and save it in a separate file with all columns to send to airline back for checking

# Remove rows with any empty/blank/null values
df_blank_issues = df[df.isnull().any(axis=1) | (df == '').any(axis=1)]
df_clean = df.drop(df_blank_issues.index)

# Save problematic rows to separate file
df_blank_issues.to_csv('airline_data_blank_data_for_review.csv', index=False)
print(f"Found {len(df_blank_issues)} rows with blank/null values")
# Out:
# Found 8200 rows with blank/null values

# %%
## analysis of blank rows and how it can effect business and why it is necessary for file named airline_data_blank_data_for_review

# %%
## code to remove all impractical flight distance but there are none
df.describe()
# Out:
#          customer_id            age  flight_distance  inflight_wifi_service  \
# count  103904.000000  103904.000000    103904.000000          100801.000000
# mean    64924.210502      39.379706      1189.448375               2.813712
# std     37463.812252      15.114964       997.147281               1.257367
# min         1.000000       7.000000        31.000000               1.000000
# 25%     32533.750000      27.000000       414.000000               2.000000
# 50%     64856.500000      40.000000       843.000000               3.000000
# 75%     97368.250000      51.000000      1743.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        departure_arrival_time_convenience  ease_of_online_booking  \
# count                        98604.000000            99417.000000
# mean                             3.224788                2.881328
# std                              1.385790                1.298773
# min                              1.000000                1.000000
# 25%                              2.000000                2.000000
# 50%                              3.000000                3.000000
# 75%                              4.000000                4.000000
# max                              5.000000                5.000000
#
#        gate_location  food_and_drink  online_boarding   seat_comfort  \
# count  103903.000000   103797.000000    101476.000000  103903.000000
# mean        2.976911        3.205430         3.328147       3.439429
# std         1.277594        1.326235         1.267246       1.319051
# min         1.000000        1.000000         1.000000       1.000000
# 25%         2.000000        2.000000         2.000000       2.000000
# 50%         3.000000        3.000000         4.000000       4.000000
# 75%         4.000000        4.000000         4.000000       5.000000
# max         5.000000        5.000000         5.000000       5.000000
#
#        inflight_entertainment  on_board_service  leg_room_service  \
# count            103890.00000     103901.000000     103432.000000
# mean                  3.35861          3.382460          3.366347
# std                   1.33251          1.288245          1.298936
# min                   1.00000          1.000000          1.000000
# 25%                   2.00000          2.000000          2.000000
# 50%                   4.00000          4.000000          4.000000
# 75%                   4.00000          4.000000          4.000000
# max                   5.00000          5.000000          5.000000
#
#        baggage_handling  checkin_service  inflight_service    cleanliness  \
# count     103904.000000    103903.000000     103901.000000  103892.000000
# mean           3.631833         3.304322          3.640533       3.286730
# std            1.180903         1.265360          1.175517       1.311873
# min            1.000000         1.000000          1.000000       1.000000
# 25%            3.000000         3.000000          3.000000       2.000000
# 50%            4.000000         3.000000          4.000000       3.000000
# 75%            5.000000         4.000000          5.000000       4.000000
# max            5.000000         5.000000          5.000000       5.000000
#
#        departure_delay_in_minutes  arrival_delay_in_minutes
# count               103904.000000             103904.000000
# mean                    14.815618                 15.133392
# std                     38.230901                 38.649776
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# 50%                      0.000000                  0.000000
# 75%                     12.000000                 13.000000
# max                   1592.000000               1584.000000

# %%
## code to remove all impractical departure delay in minutes
initial_rows = len(df)

# Identify impractical departure delays (>6 hours = 360 minutes)
impractical_mask = df['departure_delay_in_minutes'] > 360
df_delay_issues = df[impractical_mask].copy()
df = df[~impractical_mask].copy()

current_rows = len(df)

print(f"Rows before removal: {initial_rows}")
print(f"Rows after removal: {current_rows}")
print(f"Removed {len(df_delay_issues)} rows with impractical departure delays (>6 hours)")

# Save problematic rows
df_delay_issues.to_csv('airline_impractical_departure_delay_issues_for_review.csv', index=False)
# Out:
# Rows before removal: 103904
# Rows after removal: 103785
# Removed 119 rows with impractical departure delays (>6 hours)

# %%
## analysis of all removed impractical arrival delay in minutes
# Out:
# Rows before removal: 103904
# Rows after removal: 103785
# Removed 119 rows with impractical departure delays (>6 hours)

# %%
## code to remove all impractical arrival delay in minutes

initial_arrival_rows = len(df)

arrival_impractical_mask = df['arrival_delay_in_minutes'] > 30
df_arrival_issues = df[arrival_impractical_mask].copy()
df = df[~arrival_impractical_mask].copy()

current_arrival_rows = len(df)

print(f"Rows before arrival delay removal: {initial_arrival_rows}")
print(f"Rows after arrival delay removal: {current_arrival_rows}")
print(f"Removed {len(df_arrival_issues)} rows with impractical arrival delays (>30 minutes)")

df_arrival_issues.to_csv('airline_impractical_arrival_delay_issues_for_review.csv', index=False)
# Out:
# Rows before arrival delay removal: 103785
# Rows after arrival delay removal: 89240
# Removed 14545 rows with impractical arrival delays (>30 minutes)

# %%
## analysis of all removed impractical arrival delay in minutes

# %%
## code to create a new column Time_Recovered = departure_delay_in_minutes - arrival_delay_in_minutes
df['Time_Recovered'] = df['departure_delay_in_minutes'] - df['arrival_delay_in_minutes']

# %%
df.head()
# Out:
#    customer_id gender customer_type  age type_of_travel     class  \
# 0        70172      M         loyal   13       personal  eco plus
# 1         5047      M      disloyal   25       business  business
# 2       110028      F         loyal   26       business  business
# 3        24026      F         loyal   25       business  business
# 4       119299      M         loyal   61       business  business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenience  \
# 0              460                    3.0                                 4.0
# 1              235                    3.0                                 2.0
# 2             1142                    2.0                                 2.0
# 3              562                    2.0                                 5.0
# 4              214                    3.0                                 3.0
#
#    ease_of_online_booking  ...  on_board_service  leg_room_service  \
# 0                     3.0  ...               4.0               3.0
# 1                     3.0  ...               1.0               5.0
# 2                     2.0  ...               4.0               3.0
# 3                     5.0  ...               2.0               5.0
# 4                     3.0  ...               3.0               4.0
#
#    baggage_handling  checkin_service  inflight_service  cleanliness  \
# 0                 4              4.0               5.0          5.0
# 1                 3              1.0               4.0          1.0
# 2                 4              4.0               4.0          5.0
# 3                 3              1.0               4.0          2.0
# 4                 4              3.0               3.0          3.0
#
#    departure_delay_in_minutes  arrival_delay_in_minutes  \
# 0                          25                        18
# 1                           1                         6
# 2                           0                         0
# 3                          11                         9
# 4                           0                         0
#
#               satisfaction  Time_Recovered
# 0  neutral or dissatisfied               7
# 1  neutral or dissatisfied              -5
# 2                satisfied               0
# 3  neutral or dissatisfied               2
# 4                satisfied               0
#
# [5 rows x 25 columns]

# %%
# Move Time_Recovered column before satisfaction
cols = df.columns.tolist()
time_idx = cols.index('Time_Recovered')
sat_idx = cols.index('satisfaction')

cols.insert(sat_idx, cols.pop(time_idx))
df = df[cols]

# %%
df.head()
# Out:
#    customer_id gender customer_type  age type_of_travel     class  \
# 0        70172      M         loyal   13       personal  eco plus
# 1         5047      M      disloyal   25       business  business
# 2       110028      F         loyal   26       business  business
# 3        24026      F         loyal   25       business  business
# 4       119299      M         loyal   61       business  business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenience  \
# 0              460                    3.0                                 4.0
# 1              235                    3.0                                 2.0
# 2             1142                    2.0                                 2.0
# 3              562                    2.0                                 5.0
# 4              214                    3.0                                 3.0
#
#    ease_of_online_booking  ...  on_board_service  leg_room_service  \
# 0                     3.0  ...               4.0               3.0
# 1                     3.0  ...               1.0               5.0
# 2                     2.0  ...               4.0               3.0
# 3                     5.0  ...               2.0               5.0
# 4                     3.0  ...               3.0               4.0
#
#    baggage_handling  checkin_service  inflight_service  cleanliness  \
# 0                 4              4.0               5.0          5.0
# 1                 3              1.0               4.0          1.0
# 2                 4              4.0               4.0          5.0
# 3                 3              1.0               4.0          2.0
# 4                 4              3.0               3.0          3.0
#
#    departure_delay_in_minutes  arrival_delay_in_minutes  Time_Recovered  \
# 0                          25                        18               7
# 1                           1                         6              -5
# 2                           0                         0               0
# 3                          11                         9               2
# 4                           0                         0               0
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 25 columns]

# %%
## Time recovery status
df['time_recovery_status'] = df['Time_Recovered'].apply(
    lambda x: 'Recovered' if x > 0 else ('Same' if x == 0 else 'Worsened')
)

# %%
df.head()
# Out:
#    customer_id gender customer_type  age type_of_travel     class  \
# 0        70172      M         loyal   13       personal  eco plus
# 1         5047      M      disloyal   25       business  business
# 2       110028      F         loyal   26       business  business
# 3        24026      F         loyal   25       business  business
# 4       119299      M         loyal   61       business  business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenience  \
# 0              460                    3.0                                 4.0
# 1              235                    3.0                                 2.0
# 2             1142                    2.0                                 2.0
# 3              562                    2.0                                 5.0
# 4              214                    3.0                                 3.0
#
#    ease_of_online_booking  ...  leg_room_service  baggage_handling  \
# 0                     3.0  ...               3.0                 4
# 1                     3.0  ...               5.0                 3
# 2                     2.0  ...               3.0                 4
# 3                     5.0  ...               5.0                 3
# 4                     3.0  ...               4.0                 4
#
#    checkin_service  inflight_service  cleanliness  departure_delay_in_minutes  \
# 0              4.0               5.0          5.0                          25
# 1              1.0               4.0          1.0                           1
# 2              4.0               4.0          5.0                           0
# 3              1.0               4.0          2.0                          11
# 4              3.0               3.0          3.0                           0
#
#    arrival_delay_in_minutes  Time_Recovered             satisfaction  \
# 0                        18               7  neutral or dissatisfied
# 1                         6              -5  neutral or dissatisfied
# 2                         0               0                satisfied
# 3                         9               2  neutral or dissatisfied
# 4                         0               0                satisfied
#
#    time_recovery_status
# 0             Recovered
# 1              Worsened
# 2                  Same
# 3             Recovered
# 4                  Same
#
# [5 rows x 26 columns]

# %%
cols = df.columns.tolist()
recovery_idx = cols.index('time_recovery_status')
sat_idx = cols.index('satisfaction')

cols.insert(sat_idx, cols.pop(recovery_idx))
df = df[cols]

# %%
df.head()
# Out:
#    customer_id gender customer_type  age type_of_travel     class  \
# 0        70172      M         loyal   13       personal  eco plus
# 1         5047      M      disloyal   25       business  business
# 2       110028      F         loyal   26       business  business
# 3        24026      F         loyal   25       business  business
# 4       119299      M         loyal   61       business  business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenience  \
# 0              460                    3.0                                 4.0
# 1              235                    3.0                                 2.0
# 2             1142                    2.0                                 2.0
# 3              562                    2.0                                 5.0
# 4              214                    3.0                                 3.0
#
#    ease_of_online_booking  ...  leg_room_service  baggage_handling  \
# 0                     3.0  ...               3.0                 4
# 1                     3.0  ...               5.0                 3
# 2                     2.0  ...               3.0                 4
# 3                     5.0  ...               5.0                 3
# 4                     3.0  ...               4.0                 4
#
#    checkin_service  inflight_service  cleanliness  departure_delay_in_minutes  \
# 0              4.0               5.0          5.0                          25
# 1              1.0               4.0          1.0                           1
# 2              4.0               4.0          5.0                           0
# 3              1.0               4.0          2.0                          11
# 4              3.0               3.0          3.0                           0
#
#    arrival_delay_in_minutes  Time_Recovered  time_recovery_status  \
# 0                        18               7             Recovered
# 1                         6              -5              Worsened
# 2                         0               0                  Same
# 3                         9               2             Recovered
# 4                         0               0                  Same
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 26 columns]

# %%
df = df.rename(columns={'Time_Recovered': 'time_recovered'})

# %%
df['time_recovery_status'] = df['time_recovery_status'].str.lower()

# %%
df.head()
# Out:
#    customer_id gender customer_type  age type_of_travel     class  \
# 0        70172      M         loyal   13       personal  eco plus
# 1         5047      M      disloyal   25       business  business
# 2       110028      F         loyal   26       business  business
# 3        24026      F         loyal   25       business  business
# 4       119299      M         loyal   61       business  business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenience  \
# 0              460                    3.0                                 4.0
# 1              235                    3.0                                 2.0
# 2             1142                    2.0                                 2.0
# 3              562                    2.0                                 5.0
# 4              214                    3.0                                 3.0
#
#    ease_of_online_booking  ...  leg_room_service  baggage_handling  \
# 0                     3.0  ...               3.0                 4
# 1                     3.0  ...               5.0                 3
# 2                     2.0  ...               3.0                 4
# 3                     5.0  ...               5.0                 3
# 4                     3.0  ...               4.0                 4
#
#    checkin_service  inflight_service  cleanliness  departure_delay_in_minutes  \
# 0              4.0               5.0          5.0                          25
# 1              1.0               4.0          1.0                           1
# 2              4.0               4.0          5.0                           0
# 3              1.0               4.0          2.0                          11
# 4              3.0               3.0          3.0                           0
#
#    arrival_delay_in_minutes  time_recovered  time_recovery_status  \
# 0                        18               7             recovered
# 1                         6              -5              worsened
# 2                         0               0                  same
# 3                         9               2             recovered
# 4                         0               0                  same
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 26 columns]

# %%
df = df.rename(columns={'time_recovered': 'time_recovered_in_minutes'})

# %%
df.head()
# Out:
#    customer_id gender customer_type  age type_of_travel     class  \
# 0        70172      M         loyal   13       personal  eco plus
# 1         5047      M      disloyal   25       business  business
# 2       110028      F         loyal   26       business  business
# 3        24026      F         loyal   25       business  business
# 4       119299      M         loyal   61       business  business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenience  \
# 0              460                    3.0                                 4.0
# 1              235                    3.0                                 2.0
# 2             1142                    2.0                                 2.0
# 3              562                    2.0                                 5.0
# 4              214                    3.0                                 3.0
#
#    ease_of_online_booking  ...  leg_room_service  baggage_handling  \
# 0                     3.0  ...               3.0                 4
# 1                     3.0  ...               5.0                 3
# 2                     2.0  ...               3.0                 4
# 3                     5.0  ...               5.0                 3
# 4                     3.0  ...               4.0                 4
#
#    checkin_service  inflight_service  cleanliness  departure_delay_in_minutes  \
# 0              4.0               5.0          5.0                          25
# 1              1.0               4.0          1.0                           1
# 2              4.0               4.0          5.0                           0
# 3              1.0               4.0          2.0                          11
# 4              3.0               3.0          3.0                           0
#
#    arrival_delay_in_minutes  time_recovered_in_minutes  time_recovery_status  \
# 0                        18                          7             recovered
# 1                         6                         -5              worsened
# 2                         0                          0                  same
# 3                         9                          2             recovered
# 4                         0                          0                  same
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 26 columns]

# %%
## code to remove all impractical time_recovered values

initial_rows = len(df)

# Identify time_recovered values >60 or <-60
time_issue_mask = df['time_recovered_in_minutes'].abs() > 60
df_time_issues = df[time_issue_mask].copy()
df = df[~time_issue_mask].copy()

current_rows = len(df)

print(f"Rows before removal: {initial_rows}")
print(f"Rows after removal: {current_rows}")
print(f"Removed {len(df_time_issues)} rows with [time_recovered_in_minutes] > 60 minutes")

df_time_issues.to_csv('airline_impractical_time_recovered_in_minutes_issues_for_review.csv', index=False)
# Out:
# Rows before removal: 89240
# Rows after removal: 89174
# Removed 66 rows with |time_recovered| > 60 minutes

# %%
df.head()
# Out:
#    customer_id gender customer_type  age type_of_travel     class  \
# 0        70172      M         loyal   13       personal  eco plus
# 1         5047      M      disloyal   25       business  business
# 2       110028      F         loyal   26       business  business
# 3        24026      F         loyal   25       business  business
# 4       119299      M         loyal   61       business  business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenience  \
# 0              460                    3.0                                 4.0
# 1              235                    3.0                                 2.0
# 2             1142                    2.0                                 2.0
# 3              562                    2.0                                 5.0
# 4              214                    3.0                                 3.0
#
#    ease_of_online_booking  ...  leg_room_service  baggage_handling  \
# 0                     3.0  ...               3.0                 4
# 1                     3.0  ...               5.0                 3
# 2                     2.0  ...               3.0                 4
# 3                     5.0  ...               5.0                 3
# 4                     3.0  ...               4.0                 4
#
#    checkin_service  inflight_service  cleanliness  departure_delay_in_minutes  \
# 0              4.0               5.0          5.0                          25
# 1              1.0               4.0          1.0                           1
# 2              4.0               4.0          5.0                           0
# 3              1.0               4.0          2.0                          11
# 4              3.0               3.0          3.0                           0
#
#    arrival_delay_in_minutes  time_recovered_in_minutes  time_recovery_status  \
# 0                        18                          7             recovered
# 1                         6                         -5              worsened
# 2                         0                          0                  same
# 3                         9                          2             recovered
# 4                         0                          0                  same
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 26 columns]

# %%
df.to_csv('refined_dataset.csv', index=False)
